# %%
from extract_tec import extract_daily_tec

hourly, mean = extract_daily_tec("codg0010.22i")

print(hourly)
print(mean)
# Out:
# [ 9.1  9.   6.8  7.1  6.1  5.3  8.3 15.2 21.  26.5 31.4 38.6 38.7 36.4
#  36.4 35.8 37.8 34.3 23.4 16.1 14.5 12.8 11.3  9.7  7.9]
# 19.98

# %%
from extract_tec import filename_to_date

print(filename_to_date("codg0010.22i"))
print(filename_to_date("codg0320.23i"))
print(filename_to_date("codg3660.24i"))
# Out:
# 2022-01-01
# 2023-02-01
# 2024-12-31

# %%
import pandas as pd

df = pd.read_csv("../data/processed/tec_daily.csv")

print(df.shape)
print(df.head())
# Out:
# (1, 27)
#          Date  MeanTEC  TEC00  TEC01  TEC02  TEC03  TEC04  TEC05  TEC06  \
# 0  2022-01-01    19.98    9.1    9.0    6.8    7.1    6.1    5.3    8.3
#
#    TEC07  ...  TEC15  TEC16  TEC17  TEC18  TEC19  TEC20  TEC21  TEC22  TEC23  \
# 0   15.2  ...   35.8   37.8   34.3   23.4   16.1   14.5   12.8   11.3    9.7
#
#    TEC24
# 0    7.9
#
# [1 rows x 27 columns]

# %%
import pandas as pd

df = pd.read_csv("../data/processed/tec_abuja_2022_2024.csv")

print(df.head())
# Out:
#          date  daily_mean_tec  hour_00  hour_01  hour_02  hour_03  hour_04  \
# 0  2022-01-01          19.980      9.1      9.0      6.8      7.1      6.1
# 1  2022-01-02          19.680      7.7      7.5      7.0      6.2      6.3
# 2  2022-01-03          18.256     11.6      8.9      5.4      4.5      4.1
# 3  2022-01-04          17.548      9.4      8.5      5.9      4.6      4.5
# 4  2022-01-05          15.896      7.2      5.5      4.7      4.9      4.8
#
#    hour_05  hour_06  hour_07  ...  hour_15  hour_16  hour_17  hour_18  \
# 0      5.3      8.3     15.2  ...     35.8     37.8     34.3     23.4
# 1      6.0      7.8     15.9  ...     34.2     34.0     28.9     20.7
# 2      3.6      6.1     14.0  ...     30.1     30.5     28.9     23.3
# 3      3.8      6.4     14.4  ...     29.6     29.8     27.1     20.1
# 4      4.3      6.3     12.8  ...     26.8     27.4     25.2     19.4
#
#    hour_19  hour_20  hour_21  hour_22  hour_23  hour_24
# ...

# %%
df = pd.read_csv("../data/processed/master_dataset.csv")

print(df.head())
# Out:
#          date  daily_mean_tec   ssn   kp_mean  ap_daily  f107_obs  f107_adj  \
# 0  2022-01-01          19.980  48.0  2.416625      12.0      93.9      90.8
# 1  2022-01-02          19.680  27.0  2.041500       9.0      89.0      86.0
# 2  2022-01-03          18.256  10.0  2.416625      12.0      84.0      81.3
# 3  2022-01-04          17.548  10.0  1.083250       5.0      85.5      82.7
# 4  2022-01-05          15.896  23.0  0.625000       2.0      83.7      81.0
#
#    dst_daily_mean
# 0      -11.125000
# 1       -9.708333
# 2      -10.833333
# 3      -10.083333
# 4       -3.583333

# %%
print(df.shape)
print(df.columns.tolist())
print(df.info())
print(df.describe())
print(df.isnull().sum())
# Out:
# (1096, 8)
# ['date', 'daily_mean_tec', 'ssn', 'kp_mean', 'ap_daily', 'f107_obs', 'f107_adj', 'dst_daily_mean']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1096 entries, 0 to 1095
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            1096 non-null   object
#  1   daily_mean_tec  1096 non-null   float64
#  2   ssn             1096 non-null   float64
#  3   kp_mean         1096 non-null   float64
#  4   ap_daily        1096 non-null   float64
#  5   f107_obs        1095 non-null   float64
#  6   f107_adj        1095 non-null   float64
#  7   dst_daily_mean  1096 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 68.6+ KB
# None
#        daily_mean_tec          ssn      kp_mean     ap_daily     f107_obs  \
# count     1096.000000  1096.000000  1096.000000  1096.000000  1095.000000
# mean        39.681500   121.171533     1.947381    10.876825   158.625114
# ...

# %%
print(df["date"].duplicated().sum())

print(df["date"].min())
print(df["date"].max())
# Out:
# 0
# 2022-01-01
# 2024-12-31
